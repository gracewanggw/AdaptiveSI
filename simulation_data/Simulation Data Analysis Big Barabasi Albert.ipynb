# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Nodes Infected/ Susceptible Over Time

# %%
alpha = 0.5
path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
df = pd.read_csv(path)

plt.plot(df['t'], df['infected'], color='red', label='infected')
plt.plot(df['t'], df['susceptible'], color='blue', label='susceptible')
plt.xlabel('t') 
plt.ylabel('# of Nodes') 
plt.title("Alpha = " + str(alpha))
plt.legend()

# %%
alpha = 0.65
path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
df = pd.read_csv(path)

plt.plot(df['t'], df['infected'], color='red', label='infected')
plt.plot(df['t'], df['susceptible'], color='blue', label='susceptible')
plt.xlabel('t') 
plt.ylabel('# of Nodes') 
plt.title("Alpha = " + str(alpha))
plt.legend()

# %%
alpha = 0.7
path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
df = pd.read_csv(path)

plt.plot(df['t'], df['infected'], color='red', label='infected')
plt.plot(df['t'], df['susceptible'], color='blue', label='susceptible')
plt.xlabel('t') 
plt.ylabel('# of Nodes') 
plt.title("Alpha = " + str(alpha))
plt.legend()

# %%
alpha = 0.75
path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
df = pd.read_csv(path)

plt.plot(df['t'], df['infected'], color='red', label='infected')
plt.plot(df['t'], df['susceptible'], color='blue', label='susceptible')
plt.xlabel('t') 
plt.ylabel('# of Nodes') 
plt.title("Alpha = " + str(alpha))
plt.legend()

# %%
alpha = 0.8
path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
df = pd.read_csv(path)

plt.plot(df['t'], df['infected'], color='red', label='infected')
plt.plot(df['t'], df['susceptible'], color='blue', label='susceptible')
plt.xlabel('t') 
plt.ylabel('# of Nodes') 
plt.title("Alpha = " + str(alpha))
plt.legend()

# %%
alpha = 0.85
path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
df = pd.read_csv(path)

plt.plot(df['t'], df['infected'], color='red', label='infected')
plt.plot(df['t'], df['susceptible'], color='blue', label='susceptible')
plt.xlabel('t') 
plt.ylabel('# of Nodes') 
plt.title("Alpha = " + str(alpha))
plt.legend()

# %%
alpha = 0.87
path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
df = pd.read_csv(path)

plt.plot(df['t'], df['infected'], color='red', label='infected')
plt.plot(df['t'], df['susceptible'], color='blue', label='susceptible')
plt.xlabel('t') 
plt.ylabel('# of Nodes') 
plt.title("Alpha = " + str(alpha))
plt.legend()

# %%
alpha = 0.9
path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
df = pd.read_csv(path)

plt.plot(df['t'], df['infected'], color='red', label='infected')
plt.plot(df['t'], df['susceptible'], color='blue', label='susceptible')
plt.xlabel('t') 
plt.ylabel('# of Nodes') 
plt.title("Alpha = " + str(alpha))
plt.legend()

# %%
alpha = 0.95
path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
df = pd.read_csv(path)

plt.plot(df['t'], df['infected'], color='red', label='infected')
plt.plot(df['t'], df['susceptible'], color='blue', label='susceptible')
plt.xlabel('t') 
plt.ylabel('# of Nodes') 
plt.title("Alpha = " + str(alpha))
plt.legend()

# %% [markdown]
# # Edges Over Time

# %%
alpha = 0.5
path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
df = pd.read_csv(path)

plt.plot(df['t'], df['[II]'], color='red', label='[II]')
plt.plot(df['t'], df['[SS]'], color='blue', label='[SS]')
plt.plot(df['t'], df['[IS]'], color='purple', label='[IS]')
plt.xlabel('t') 
plt.ylabel('# of Edges') 
plt.title("Alpha = " + str(alpha) + " u = 0.5" )
plt.legend()

# %%
alpha = 0.65
path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
df = pd.read_csv(path)

plt.plot(df['t'], df['[II]'], color='red', label='[II]')
plt.plot(df['t'], df['[SS]'], color='blue', label='[SS]')
plt.plot(df['t'], df['[IS]'], color='purple', label='[IS]')
plt.xlabel('t') 
plt.ylabel('# of Edges')
plt.title("Alpha = " + str(alpha))
plt.legend()

# %%
alpha = 0.7
path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
df = pd.read_csv(path)

plt.plot(df['t'], df['[II]'], color='red', label='[II]')
plt.plot(df['t'], df['[SS]'], color='blue', label='[SS]')
plt.plot(df['t'], df['[IS]'], color='purple', label='[IS]')
plt.xlabel('t') 
plt.ylabel('# of Edges') 
plt.title("Alpha = " + str(alpha))
plt.legend()

# %%
alpha = 0.75
path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
df = pd.read_csv(path)

plt.plot(df['t'], df['[II]'], color='red', label='[II]')
plt.plot(df['t'], df['[SS]'], color='blue', label='[SS]')
plt.plot(df['t'], df['[IS]'], color='purple', label='[IS]')
plt.xlabel('t') 
plt.ylabel('# of Edges')
plt.title("Alpha = " + str(alpha))
plt.legend()

# %%
alpha = 0.8
path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
df = pd.read_csv(path)

plt.plot(df['t'], df['[II]'], color='red', label='[II]')
plt.plot(df['t'], df['[SS]'], color='blue', label='[SS]')
plt.plot(df['t'], df['[IS]'], color='purple', label='[IS]')
plt.xlabel('t') 
plt.ylabel('# of Edges') 
plt.title("Alpha = " + str(alpha))
plt.legend()

# %%
alpha = 0.85
path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
df = pd.read_csv(path)

plt.plot(df['t'], df['[II]'], color='red', label='[II]')
plt.plot(df['t'], df['[SS]'], color='blue', label='[SS]')
plt.plot(df['t'], df['[IS]'], color='purple', label='[IS]')
plt.xlabel('t') 
plt.ylabel('# of Edges') 
plt.title("Alpha = " + str(alpha))
plt.legend()

# %%
alpha = 0.87
path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
df = pd.read_csv(path)

plt.plot(df['t'], df['[II]'], color='red', label='[II]')
plt.plot(df['t'], df['[SS]'], color='blue', label='[SS]')
plt.plot(df['t'], df['[IS]'], color='purple', label='[IS]')
plt.xlabel('t') 
plt.ylabel('# of Edges') 
plt.title("Alpha = " + str(alpha))
plt.legend()

# %%
alpha = 0.9
path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
df = pd.read_csv(path)

plt.plot(df['t'], df['[II]'], color='red', label='[II]')
plt.plot(df['t'], df['[SS]'], color='blue', label='[SS]')
plt.plot(df['t'], df['[IS]'], color='purple', label='[IS]')
plt.xlabel('t') 
plt.ylabel('# of Edges') 
plt.title("Alpha = " + str(alpha))
plt.legend()

# %%
alpha = 0.95
path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
df = pd.read_csv(path)

plt.plot(df['t'], df['[II]'], color='red', label='[II]')
plt.plot(df['t'], df['[SS]'], color='blue', label='[SS]')
plt.plot(df['t'], df['[IS]'], color='purple', label='[IS]')
plt.xlabel('t') 
plt.ylabel('# of Edges')
plt.title("Alpha = " + str(alpha) + " u = 0.5" )
plt.legend()

# %%
alphas = [0.4, 0.5, 0.65, 0.7, 0.75, 0.8, 0.85, 0.87, 0.9, 0.95]

for alpha in alphas:
    path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
    df = pd.read_csv(path)
    infected = []
    susceptible = []
    time = []
    is_edges = []
    tot_edges = []
    for inf in df['infected'] :
        infected.append(inf/300)

    for sus in df['susceptible'] :
        susceptible.append(sus/300)

    for ss in df['[SS]']:
        tot_edges.append(ss)

    for i in range(0,len(tot_edges)):
        tot_edges[i] += df['[II]'][i]
        tot_edges[i] += df['[IS]'][i]
        is_edges.append(df['[IS]'][i]/tot_edges[i])
    
    plt.plot(infected, is_edges, label='alpha = ' + str(alpha))
    plt.xlabel('Fraction of Nodes Infected') 
    plt.ylabel('Fraction of Edges Disjunct') 
    plt.title('Proportion of [IS] vs. Proportion of Infecteds: Barabasi-Albert')
    plt.legend()

# %%
alphas = [0.5, 0.65, 0.7, 0.75, 0.8, 0.85, 0.87, 0.9, 0.95]

for alpha in alphas:
    path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
    df = pd.read_csv(path)
    plt.plot(df['t'], df['infected'], label='alpha = ' + str(alpha))
    plt.xlabel('N(t)') 
    plt.ylabel('t') 
    plt.title('Aggregate Infecteds: Barabasi-Albert')
    plt.legend()

# %%
alphas = [0.5, 0.65, 0.7, 0.75, 0.8, 0.85, 0.87, 0.9, 0.95]

for alpha in alphas:
    path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
    df = pd.read_csv(path)
    plt.plot(df['t'], df['susceptible'], label='alpha = ' + str(alpha))
    plt.xlabel('t') 
    plt.ylabel('# of Nodes') 
    plt.title('Aggregate Susceptibles: Barabasi-Albert u = 0.5')
    plt.legend()

# %%
alphas = [0.5, 0.65, 0.7, 0.75, 0.8, 0.85, 0.87, 0.9, 0.95]

for alpha in alphas:
    path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
    df = pd.read_csv(path)
    plt.plot(df['t'], df['[SS]'], label='alpha = ' + str(alpha))
    plt.xlabel('t') 
    plt.ylabel('# of Edges')
    plt.title('Aggregate [SS]: Barabasi-Albert u = 0.5')
    plt.legend()

# %%
alphas = [0.5, 0.65, 0.7, 0.75, 0.8, 0.85, 0.87, 0.9, 0.95]

for alpha in alphas:
    path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
    df = pd.read_csv(path)
    plt.plot(df['t'], df['[II]'], label='alpha = ' + str(alpha))
    plt.xlabel('t') 
    plt.ylabel('# of Edges')
    plt.title('Aggregate [II]')
    plt.legend()

# %%
alphas = [0.5, 0.65, 0.7, 0.75, 0.8, 0.85, 0.87, 0.9, 0.95]

for alpha in alphas:
    path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
    df = pd.read_csv(path)
    plt.plot(df['t'], df['[IS]'], label='alpha = ' + str(alpha))
    plt.xlabel('t') 
    plt.ylabel('# of Edges')
    plt.title('Aggregate [IS]: Barabasi-Albert')
    plt.legend()

# %% [markdown]
# # Different Initial Infection Value

# %%
alphas = [0.5, 0.75, 0.95]
us = [0.5]

for alpha, u in alphas, us:
    path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
    df = pd.read_csv(path)
    infected = []
    susceptible = []
    time = []
    is_edges = []
    tot_edges = []
    for inf in df['infected'] :
        infected.append(inf/300)

    for sus in df['susceptible'] :
        susceptible.append(sus/300)

    for ss in df['[SS]']:
        tot_edges.append(ss)

    for i in range(0,len(tot_edges)):
        tot_edges[i] += df['[II]'][i]
        tot_edges[i] += df['[IS]'][i]
        is_edges.append(df['[IS]'][i]/tot_edges[i])
    
    plt.plot(infected, is_edges, label='alpha = ' + str(alpha))
    
    path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_u' + u 
    df = pd.read_csv(path)
    infected = []
    susceptible = []
    time = []
    is_edges = []
    tot_edges = []
    for inf in df['infected'] :
        infected.append(inf/300)

    for sus in df['susceptible'] :
        susceptible.append(sus/300)

    for ss in df['[SS]']:
        tot_edges.append(ss)

    for i in range(0,len(tot_edges)):
        tot_edges[i] += df['[II]'][i]
        tot_edges[i] += df['[IS]'][i]
        is_edges.append(df['[IS]'][i]/tot_edges[i])
    
    plt.plot(infected, is_edges, label='alpha = ' + str(alpha))
    plt.xlabel('Fraction of Nodes Infected') 
    plt.ylabel('Fraction of Edges Disjunct') 
    plt.title('Proportion of [IS] vs. Proportion of Infecteds: Barabasi-Albert')
    plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-2358233d35f1> in <module>
#       2 us = [0.5]
#       3
# ----> 4 for alpha, u in alphas, us:
#       5     path = '/Users/gracewang/Desktop/Dartmouth/MATH36/AdaptiveSIS/simulation_data/alpha' + str(alpha) + '/simulation_data_' + str(alpha) + '_big'
#       6     df = pd.read_csv(path)
#
# ValueError: too many values to unpack (expected 2)
